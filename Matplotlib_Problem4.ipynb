# %% [markdown]
# #Matplotlib – Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
# ax = plt.axes([0.3,0.5,0.8,0.8]) # this is the one way to add axes
# we can also add axes to an existing figure using the add_axes() method.
# This method takes a list of four values: [left, bottom, width, height],
# where all values are in the range [0, 1] and represent the fraction of the figure's width and height.
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
# importing library
import matplotlib.pyplot as plt

# Some data to display
x = [1, 2, 3]
y = [0, 1, 0]
z = [1, 0, 1]
#creating 2 subplots
fig, ax = plt.subplots(2)
#plot and show
ax[0].plot(x,y)
ax[1].plot(x,z)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,2,0.01)
y = 1 + np.sin(2 * np.pi * x)
fig,((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(3,2)
ax1.plot(x,y,color = 'orange')
ax2.plot(x,y,color = 'red')
ax3.plot(x,y,color = 'blue')
ax4.plot(x,y,color = 'green')
ax5.plot(x,y,color = 'black')
ax6.plot(x,y,color = 'magenta')

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots(2,2)
x = [1,2,3]
y = [4,5,6]
ax[0,0].plot(x,y)
ax[0,1].scatter(x,y)
ax[1,0].bar(x,y)
ax[1,1].hist([1,3,3,4,3,4,1,1,1,2,2,4])
# set titles for all the subplots
ax[0,0].set_title('line plot')
ax[0,1].set_title('scatter plot')
ax[1,0].set_title('bar plot')
ax[1,1].set_title('hitogram')
# Adjust layout to prevent overlap
plt.tight_layout()
#Display the graphs
plt.show()
